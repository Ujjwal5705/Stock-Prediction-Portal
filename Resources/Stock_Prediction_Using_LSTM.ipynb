# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime

# %% [markdown]
# # 1.Data Collection

# %%
now = datetime.now()

ticker = 'AAPL'
end = now
start = datetime(now.year-10, now.month, now.day)
df = yf.download(ticker, start, end, auto_adjust=False)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2015-07-09   26.891689   30.017500   31.014999   29.805000   30.962500
# 2015-07-10   27.610630   30.820000   30.962500   30.302500   30.485001
# 2015-07-13   28.143675   31.415001   31.440001   31.080000   31.257500
# 2015-07-14   28.132477   31.402500   31.592501   31.260000   31.510000
# 2015-07-15   28.403473   31.705000   31.787500   31.395000   31.430000
# ...                ...         ...         ...         ...         ...
# 2025-07-02  212.440002  212.440002  213.339996  208.139999  208.910004
# 2025-07-03  213.550003  213.550003  214.649994  211.809998  212.149994
# 2025-07-07  209.949997  209.949997  216.229996  208.800003  212.679993
# 2025-07-08  210.009995  210.009995  211.429993  208.449997  210.100006
# 2025-07-09  209.770004  209.770004  210.899994  207.220001  209.529999
#
# Price          Volume
# Ticker           AAPL
# Date
# 2015-07-09  314380000
# 2015-07-10  245418000
# 2015-07-13  165762000
# 2015-07-14  127072400
# 2015-07-15  134596800
# ...               ...
# 2025-07-02   67941800
# 2025-07-03   34955800
# 2025-07-07   50229000
# 2025-07-08   42780600
# 2025-07-09   28784610
#
# [2515 rows x 6 columns]

# %% [markdown]
# # 2. Data Exploration & Visualization

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (2515, 6)

# %%
df.isna().sum()
# Out:
# Price      Ticker
# Adj Close  AAPL      0
# Close      AAPL      0
# High       AAPL      0
# Low        AAPL      0
# Open       AAPL      0
# Volume     AAPL      0
# dtype: int64

# %%
df.describe()
# Out:
# Price     Adj Close        Close         High          Low         Open  \
# Ticker         AAPL         AAPL         AAPL         AAPL         AAPL
# count   2515.000000  2515.000000  2515.000000  2515.000000  2515.000000
# mean     103.664136   105.814211   106.875782   104.637216   105.711923
# std       68.969300    68.550533    69.224512    67.785921    68.472852
# min       20.647455    22.584999    22.917500    22.367500    22.500000
# 25%       39.118607    41.473751    42.052502    41.059999    41.458750
# 50%       90.251755    92.845001    93.945000    92.010002    92.500000
# 75%      163.964622   166.229996   168.135002   164.915001   166.290001
# max      258.396667   259.019989   260.100006   257.630005   258.190002
#
# Price         Volume
# Ticker          AAPL
# count   2.515000e+03
# mean    1.095681e+08
# std     6.443148e+07
# min     2.323470e+07
# 25%     6.668210e+07
# 50%     9.430040e+07
# 75%     1.335536e+08
# max     6.488252e+08

# %%
df.dtypes
# Out:
# Price      Ticker
# Adj Close  AAPL      float64
# Close      AAPL      float64
# High       AAPL      float64
# Low        AAPL      float64
# Open       AAPL      float64
# Volume     AAPL        int64
# dtype: object

# %%
df.head()
# Out:
# Price       Adj Close      Close       High      Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL     AAPL       AAPL       AAPL
# Date
# 2015-07-09  26.891689  30.017500  31.014999  29.8050  30.962500  314380000
# 2015-07-10  27.610630  30.820000  30.962500  30.3025  30.485001  245418000
# 2015-07-13  28.143675  31.415001  31.440001  31.0800  31.257500  165762000
# 2015-07-14  28.132477  31.402500  31.592501  31.2600  31.510000  127072400
# 2015-07-15  28.403473  31.705000  31.787500  31.3950  31.430000  134596800

# %%
df = df.reset_index()
df
# Out:
# Price        Date   Adj Close       Close        High         Low        Open  \
# Ticker                   AAPL        AAPL        AAPL        AAPL        AAPL
# 0      2015-07-09   26.891689   30.017500   31.014999   29.805000   30.962500
# 1      2015-07-10   27.610630   30.820000   30.962500   30.302500   30.485001
# 2      2015-07-13   28.143675   31.415001   31.440001   31.080000   31.257500
# 3      2015-07-14   28.132477   31.402500   31.592501   31.260000   31.510000
# 4      2015-07-15   28.403473   31.705000   31.787500   31.395000   31.430000
# ...           ...         ...         ...         ...         ...         ...
# 2510   2025-07-02  212.440002  212.440002  213.339996  208.139999  208.910004
# 2511   2025-07-03  213.550003  213.550003  214.649994  211.809998  212.149994
# 2512   2025-07-07  209.949997  209.949997  216.229996  208.800003  212.679993
# 2513   2025-07-08  210.009995  210.009995  211.429993  208.449997  210.100006
# 2514   2025-07-09  209.770004  209.770004  210.899994  207.220001  209.529999
#
# Price      Volume
# Ticker       AAPL
# 0       314380000
# 1       245418000
# 2       165762000
# 3       127072400
# 4       134596800
# ...           ...
# 2510     67941800
# 2511     34955800
# 2512     50229000
# 2513     42780600
# 2514     28784610
#
# [2515 rows x 7 columns]

# %%
df.columns
# Out:
# MultiIndex([(     'Date',     ''),
#             ('Adj Close', 'AAPL'),
#             (    'Close', 'AAPL'),
#             (     'High', 'AAPL'),
#             (      'Low', 'AAPL'),
#             (     'Open', 'AAPL'),
#             (   'Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
plt.figure(figsize=(12, 5));
plt.plot(df['Close']);
plt.title(ticker);
plt.xlabel('Days');
plt.ylabel('Price');
